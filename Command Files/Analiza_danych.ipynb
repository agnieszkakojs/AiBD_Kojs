# %%
import pandas as pd

# %%
data = pd.read_csv('/home/student/AiBD_Kojs/Original Data/earthquake_data.csv')
data.head()

col1 = 'Worried about earthquakes'
col2 = 'Worried about the Big One'
col3 = 'The "Big One" will occur in your lifetime?'
col4 = 'Experienced an earthquake'
col5 = 'Take precautions for an earthquake'
col6 = 'Familar with the San Andreas Fault line'
col7 = 'Familar with the Yellowstone Supervolcano'
col8 = 'Age'
col9 = 'Gender'
col10 = 'Total household combined money'
col11 = 'US Region'

copy_data = data
new_column_name = [col1, col2, col3, col4, col5, col6, col7, col8, col9, col10, col11]

copy_data.columns = new_column_name
copy_data.head(50)
# Out:
#    Worried about earthquakes Worried about the Big One  \
# 0         Not at all worried            Not so worried
# 1           Somewhat worried              Very worried
# 2             Not so worried          Somewhat worried
# 3             Not so worried            Not so worried
# 4             Not so worried            Not so worried
# 5         Not at all worried        Not at all worried
# 6               Very worried        Not at all worried
# 7         Not at all worried        Not at all worried
# 8         Not at all worried        Not at all worried
# 9         Not at all worried        Not at all worried
# 10        Not at all worried            Not so worried
# 11        Not at all worried        Not at all worried
# 12         Extremely worried              Very worried
# 13          Somewhat worried              Very worried
# 14            Not so worried            Not so worried
# 15            Not so worried          Somewhat worried
# 16        Not at all worried        Not at all worried
# 17            Not so worried          Somewhat worried
# 18            Not so worried            Not so worried
# 19              Very worried         Extremely worried
# 20        Not at all worried        Not at all worried
# 21        Not at all worried        Not at all worried
# 22        Not at all worried        Not at all worried
# 23            Not so worried              Very worried
# 24        Not at all worried        Not at all worried
# 25         Extremely worried         Extremely worried
# 26        Not at all worried        Not at all worried
# 27        Not at all worried        Not at all worried
# 28          Somewhat worried              Very worried
# 29            Not so worried            Not so worried
# 30            Not so worried          Somewhat worried
# 31          Somewhat worried          Somewhat worried
# 32        Not at all worried          Somewhat worried
# 33            Not so worried            Not so worried
# 34          Somewhat worried          Somewhat worried
# 35        Not at all worried        Not at all worried
# 36        Not at all worried        Not at all worried
# 37        Not at all worried        Not at all worried
# 38          Somewhat worried          Somewhat worried
# 39        Not at all worried        Not at all worried
# 40          Somewhat worried          Somewhat worried
# 41        Not at all worried        Not at all worried
# 42            Not so worried          Somewhat worried
# 43              Very worried              Very worried
# 44          Somewhat worried          Somewhat worried
# 45        Not at all worried          Somewhat worried
# 46            Not so worried              Very worried
# 47         Extremely worried         Extremely worried
# 48        Not at all worried        Not at all worried
# 49          Somewhat worried            Not so worried
#
#    The "Big One" will occur in your lifetime?    Experienced an earthquake  \
# 0                                          No  Yes, one or more minor ones
# 1                                          No  Yes, one or more minor ones
# 2                                          No  Yes, one or more minor ones
# 3                                          No  Yes, one or more minor ones
# 4                                         Yes  Yes, one or more minor ones
# 5                                          No  Yes, one or more minor ones
# 6                                         Yes  Yes, one or more major ones
# 7                                          No                           No
# 8                                          No  Yes, one or more minor ones
# 9                                          No                           No
# 10                                         No  Yes, one or more major ones
# 11                                         No                           No
# 12                                        Yes                          NaN
# 13                                        Yes  Yes, one or more minor ones
# 14                                         No                           No
# 15                                        Yes  Yes, one or more minor ones
# 16                                         No                           No
# 17                                        Yes  Yes, one or more minor ones
# 18                                        Yes  Yes, one or more minor ones
# 19                                        Yes  Yes, one or more minor ones
# 20                                         No                           No
# 21                                         No                           No
# 22                                         No  Yes, one or more minor ones
# 23                                        Yes  Yes, one or more minor ones
# 24                                        Yes  Yes, one or more minor ones
# 25                                         No                           No
# 26                                         No  Yes, one or more minor ones
# 27                                         No  Yes, one or more minor ones
# 28                                         No                           No
# 29                                         No                           No
# 30                                        Yes  Yes, one or more minor ones
# 31                                         No  Yes, one or more minor ones
# 32                                        Yes  Yes, one or more minor ones
# 33                                        Yes                           No
# 34                                        Yes  Yes, one or more minor ones
# 35                                         No  Yes, one or more major ones
# 36                                         No                           No
# 37                                        Yes                           No
# 38                                        Yes  Yes, one or more minor ones
# 39                                         No  Yes, one or more minor ones
# 40                                        Yes  Yes, one or more major ones
# 41                                         No                           No
# 42                                        Yes  Yes, one or more major ones
# 43                                        Yes  Yes, one or more minor ones
# 44                                        Yes  Yes, one or more minor ones
# 45                                        Yes  Yes, one or more minor ones
# 46                                        Yes                           No
# 47                                        Yes  Yes, one or more major ones
# 48                                         No                           No
# 49                                        Yes  Yes, one or more minor ones
#
#    Take precautions for an earthquake Familar with the San Andreas Fault line  \
# 0                                  No                       Somewhat familiar
# 1                                  No                     Not at all familiar
# 2                                  No                           Very familiar
# 3                                  No                           Very familiar
# 4                                  No                       Somewhat familiar
# 5                                  No                           Very familiar
# 6                                 Yes                                     NaN
# 7                                  No                         Not so familiar
# 8                                  No                           Very familiar
# 9                                  No                     Not at all familiar
# 10                                 No                       Somewhat familiar
# 11                                 No                      Extremely familiar
# 12                                NaN                                     NaN
# 13                                 No                       Somewhat familiar
# 14                                 No                           Very familiar
# 15                                 No                       Somewhat familiar
# 16                                 No                       Somewhat familiar
# 17                                 No                         Not so familiar
# 18                                 No                       Somewhat familiar
# 19                                 No                       Somewhat familiar
# 20                                 No                       Somewhat familiar
# 21                                 No                       Somewhat familiar
# 22                                 No                     Not at all familiar
# 23                                 No                           Very familiar
# 24                                 No                       Somewhat familiar
# 25                                 No                         Not so familiar
# 26                                 No                           Very familiar
# 27                                 No                      Extremely familiar
# 28                                 No                           Very familiar
# 29                                 No                         Not so familiar
# 30                                 No                         Not so familiar
# 31                                 No                     Not at all familiar
# 32                                 No                       Somewhat familiar
# 33                                 No                         Not so familiar
# 34                                Yes                       Somewhat familiar
# 35                                Yes                      Extremely familiar
# 36                                 No                       Somewhat familiar
# 37                                 No                       Somewhat familiar
# 38                                Yes                           Very familiar
# 39                                 No                      Extremely familiar
# 40                                 No                     Not at all familiar
# 41                                 No                         Not so familiar
# 42                                Yes                      Extremely familiar
# 43                                Yes                         Not so familiar
# 44                                 No                         Not so familiar
# 45                                Yes                     Not at all familiar
# 46                                Yes                       Somewhat familiar
# 47                                Yes                      Extremely familiar
# 48                                 No                      Extremely familiar
# 49                                 No                      Extremely familiar
#
#    Familar with the Yellowstone Supervolcano      Age Gender  \
# 0                            Not so familiar  18 - 29   Male
# 1                        Not at all familiar  18 - 29   Male
# 2                          Somewhat familiar  18 - 29   Male
# 3                            Not so familiar  18 - 29   Male
# 4                         Extremely familiar  18 - 29   Male
# 5                            Not so familiar  18 - 29   Male
# 6                                        NaN      NaN    NaN
# 7                        Not at all familiar  18 - 29   Male
# 8                          Somewhat familiar  18 - 29   Male
# 9                            Not so familiar  18 - 29   Male
# 10                           Not so familiar  18 - 29   Male
# 11                        Extremely familiar  18 - 29   Male
# 12                                       NaN      NaN    NaN
# 13                           Not so familiar  18 - 29   Male
# 14                         Somewhat familiar  18 - 29   Male
# 15                         Somewhat familiar  18 - 29   Male
# 16                         Somewhat familiar  18 - 29   Male
# 17                         Somewhat familiar  18 - 29   Male
# 18                         Somewhat familiar  30 - 44   Male
# 19                           Not so familiar  30 - 44   Male
# 20                         Somewhat familiar  18 - 29   Male
# 21                             Very familiar  30 - 44   Male
# 22                       Not at all familiar  18 - 29   Male
# 23                             Very familiar  18 - 29   Male
# 24                         Somewhat familiar  30 - 44   Male
# 25                           Not so familiar  18 - 29   Male
# 26                             Very familiar  30 - 44   Male
# 27                           Not so familiar  30 - 44   Male
# 28                         Somewhat familiar  30 - 44   Male
# 29                       Not at all familiar  18 - 29   Male
# 30                           Not so familiar  18 - 29   Male
# 31                       Not at all familiar  18 - 29   Male
# 32                         Somewhat familiar  30 - 44   Male
# 33                         Somewhat familiar  18 - 29   Male
# 34                         Somewhat familiar  30 - 44   Male
# 35                        Extremely familiar  18 - 29   Male
# 36                         Somewhat familiar  18 - 29   Male
# 37                           Not so familiar  18 - 29   Male
# 38                             Very familiar  18 - 29   Male
# 39                        Extremely familiar  30 - 44   Male
# 40                       Not at all familiar  30 - 44   Male
# 41                           Not so familiar  18 - 29   Male
# 42                             Very familiar  45 - 59   Male
# 43                             Very familiar  45 - 59   Male
# 44                           Not so familiar  18 - 29   Male
# 45                       Not at all familiar  18 - 29   Male
# 46                         Somewhat familiar  18 - 29   Male
# 47                        Extremely familiar  30 - 44   Male
# 48                        Extremely familiar  18 - 29   Male
# 49                             Very familiar  30 - 44   Male
#
#    Total household combined money           US Region
# 0            Prefer not to answer         New England
# 1              $75,000 to $99,999  East North Central
# 2              $10,000 to $24,999             Pacific
# 3              $25,000 to $49,999  West South Central
# 4                 $200,000 and up     Middle Atlantic
# 5              $25,000 to $49,999  East North Central
# 6                             NaN                 NaN
# 7            Prefer not to answer      South Atlantic
# 8            Prefer not to answer  East North Central
# 9              $10,000 to $24,999  East North Central
# 10             $50,000 to $74,999  West North Central
# 11             $25,000 to $49,999  East South Central
# 12                            NaN                 NaN
# 13                   $0 to $9,999             Pacific
# 14           $100,000 to $124,999         New England
# 15             $50,000 to $74,999  East North Central
# 16             $25,000 to $49,999  East North Central
# 17             $75,000 to $99,999  East North Central
# 18             $25,000 to $49,999             Pacific
# 19             $10,000 to $24,999             Pacific
# 20             $50,000 to $74,999            Mountain
# 21             $75,000 to $99,999      South Atlantic
# 22             $50,000 to $74,999     Middle Atlantic
# 23             $75,000 to $99,999     Middle Atlantic
# 24             $25,000 to $49,999  East North Central
# 25             $10,000 to $24,999                 NaN
# 26             $75,000 to $99,999  East North Central
# 27             $75,000 to $99,999     Middle Atlantic
# 28             $25,000 to $49,999  East North Central
# 29             $25,000 to $49,999      South Atlantic
# 30             $25,000 to $49,999  East North Central
# 31                   $0 to $9,999  East North Central
# 32             $25,000 to $49,999                 NaN
# 33             $10,000 to $24,999                 NaN
# 34           $100,000 to $124,999  East South Central
# 35             $10,000 to $24,999             Pacific
# 36           $175,000 to $199,999         New England
# 37                   $0 to $9,999  West North Central
# 38           $125,000 to $149,999             Pacific
# 39             $75,000 to $99,999  East North Central
# 40             $25,000 to $49,999                 NaN
# 41           $100,000 to $124,999            Mountain
# 42             $50,000 to $74,999             Pacific
# 43             $10,000 to $24,999             Pacific
# 44             $50,000 to $74,999             Pacific
# 45                   $0 to $9,999             Pacific
# 46                   $0 to $9,999  West South Central
# 47                $200,000 and up            Mountain
# 48             $75,000 to $99,999      South Atlantic
# 49           $150,000 to $174,999     Middle Atlantic
