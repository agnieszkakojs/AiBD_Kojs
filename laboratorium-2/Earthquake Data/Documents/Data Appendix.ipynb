# %% [markdown]
# # Data Appendix
# ## Książka kodów i przedwonik użytkownika

# %% [markdown]
# ### Dla każdej zmiennej
# #### Pierwsza zmienna: "Worried about earthquakes"
# - Zmienna została wyodrębniona z pliku "earthquake_data.csv" z folderu Original Data. Zmienna powstała z pytania "In general, how worried are you about earthquakes?"
# - Wszystkie obserwacje posiadały prawidłowe dane. Nie było żadnych błędnych wartości.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
def print_img(name):
    img = mpimg.imread(f'C:/Users/lenovo/Desktop/studia/Semestr V/Anliza i Bazy Danych/AiBD_Kojs/laboratorium-2/Analysis Data/{name}')
    plt.imshow(img)
    plt.axis('off')
    plt.tight_layout()
    plt.show()

print_img('1_image.png')

# %% [markdown]
# #### Druga zmienna: "Worried about the Big One"
# - Zmienna została wyodrębniona z pliku "earthquake_data.csv" z folderu Original Data. Zmienna powstała z pytania "How worried are you about the Big One, a massive, catastrophic earthquake?"
# - Wszystkie obserwacje posiadały prawidłowe dane. Nie było żadnych błędnych wartości.

# %%
print_img('2_image.png')

# %% [markdown]
# #### Trzecia zmienna: 'The "Big One" will occur in your lifetime?'
# - Zmienna została wyodrębniona z pliku "earthquake_data.csv" z folderu Original Data. Zmienna powstała z pytania "Do you think the "Big One" will occur in your lifetime?"
# - Wszystkie obserwacje posiadały prawidłowe dane. Nie było żadnych błędnych wartości.

# %%
print_img('3_image.png')

# %% [markdown]
# #### Czwarta zmienna: 'Experienced an earthquake'
# - Zmienna została wyodrębniona z pliku "earthquake_data.csv" z folderu Original Data. Zmienna powstała z pytania "Have you ever experienced an earthquake? "
# - 7 z podanych obserwacji były niepoprawna.

# %%
print_img('4_image.png')

# %% [markdown]
# #### Piąta zmienna: 'Take precautions for an earthquake'
# - Zmienna została wyodrębniona z pliku "earthquake_data.csv" z folderu Original Data. Zmienna powstała z pytania "Have you or anyone in your household taken any precautions for an earthquake (packed an earthquake survival kit, prepared an evacuation plan, etc.)?"
# - 7 z podanych obserwacji były niepoprawna.

# %%
print_img('5_image.png')

# %% [markdown]
# #### Szósta zmienna: 'Familar with the San Andreas Fault line'
# - Zmienna została wyodrębniona z pliku "earthquake_data.csv" z folderu Original Data. Zmienna powstała z pytania "How familiar are you with the San Andreas Fault line?"
# - 12 z podanych obserwacji były niepoprawna.

# %%
print_img('6_image.png')

# %% [markdown]
# #### Siódma zmienna: 'Familar with the Yellowstone Supervolcano'
# - Zmienna została wyodrębniona z pliku "earthquake_data.csv" z folderu Original Data. Zmienna powstała z pytania "How familiar are you with the Yellowstone Supervolcano?"
# - 12 z podanych obserwacji były niepoprawna.

# %%
print_img('7_image.png')

# %% [markdown]
# #### Ósma zmienna: 'Age'
# - Zmienna została wyodrębniona z pliku "earthquake_data.csv" z folderu Original Data. Pozostała ona taka sama jak w oryginalnym pliku.
# - 12 z podanych obserwacji były niepoprawna.

# %%
print_img('8_image.png')

# %% [markdown]
# #### Dziewiąta zmienna: 'Gender'
# - Zmienna została wyodrębniona z pliku "earthquake_data.csv" z folderu Original Data. Zmienna powstała z pytania "What is your gender?"
# - 12 z podanych obserwacji były niepoprawna.

# %%
print_img('9_image.png')

# %% [markdown]
# #### Dziesiąta zmienna: 'Total household combined money'
# - Zmienna została wyodrębniona z pliku "earthquake_data.csv" z folderu Original Data. Zmienna powstała z pytania "How much total combined money did all members of your HOUSEHOLD earn last year?"
# - 12 z podanych obserwacji były niepoprawna.

# %%
print_img('10_image.png')

# %% [markdown]
# #### Jedynasta zmienna: 'US Region'
# - Zmienna została wyodrębniona z pliku "earthquake_data.csv" z folderu Original Data. Pozostała ona taka sama jak w oryginalnym pliku.
# - 35 z podanych obserwacji były niepoprawna.

# %%
print_img('11_image.png')
