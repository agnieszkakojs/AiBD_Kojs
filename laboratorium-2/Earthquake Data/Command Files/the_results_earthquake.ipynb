# %% [markdown]
# # Generowanie rezultatów do analizy

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Wczytanie pliku, z którego będą generowane wykresy
data_res = pd.read_csv(r'C:\Users\lenovo\Desktop\studia\Semestr V\Anliza i Bazy Danych\AiBD_Kojs\laboratorium-2\Earthquake Data\Analysis Data\earthquake_data_newframe.csv')

# %%
# Zależność odpowiedzi tak i nie od płci
data_res.groupby(['Gender', 'The "Big One" will occur in your lifetime?']).size().unstack().plot(kind='bar',stacked=False)
plt.title('The "Big One" will occur in your lifetime?')
plt.legend(loc='lower right')
plt.grid()
plt.tight_layout()
plt.savefig(rf'C:\Users\lenovo\Desktop\studia\Semestr V\Anliza i Bazy Danych\AiBD_Kojs\laboratorium-2\Earthquake Data\Analysis Data\plot-gender-bigone.png')
plt.show()

# %%
# Zależność odpowiedzi na pytanie od wieku
data_res.groupby(['Age', 'The "Big One" will occur in your lifetime?']).size().unstack().plot(kind='bar',stacked=False, legend=True)
plt.title('The "Big One" will occur in your lifetime?')
plt.legend(loc='lower right')
plt.grid()
plt.tight_layout()
plt.savefig(rf'C:\Users\lenovo\Desktop\studia\Semestr V\Anliza i Bazy Danych\AiBD_Kojs\laboratorium-2\Earthquake Data\Analysis Data\plot-age-bigone.png')
plt.show()
